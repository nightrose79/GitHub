# %%
from pyalgotrade.stratanalyzer import returns
from pyalgotrade.stratanalyzer import sharpe
from pyalgotrade.stratanalyzer import drawdown
from pyalgotrade.stratanalyzer import trades

from pyalgotrade import strategy
from pyalgotrade.strategy import position
from pyalgotrade import plotter
from pyalgotrade.tools import yahoofinance
from pyalgotrade.barfeed import yahoofeed
from pyalgotrade.technical import bollinger
from pyalgotrade.stratanalyzer import sharpe
import BBands_mod
import matplotlib.pyplot as plt 

# Load the yahoo feed from the CSV file
feed = yahoofeed.Feed()
feed.addBarsFromCSV("orcl", "data_daily.csv")

#def main(plot):
instrument = "orcl"
bBandsPeriod = 48
smaPeriod_short=20
smaPeriod_long=35
slopePeriod =40
plot=True

# Evaluate the strategy with the feed's bars.
myStrategy = BBands_mod.BBands(feed, instrument, bBandsPeriod,smaPeriod_short,smaPeriod_long,slopePeriod)
  
if plot:
    plt = plotter.StrategyPlotter(myStrategy, True, True, True)
    plt.getInstrumentSubplot(instrument).addDataSeries("upper", myStrategy.getBollingerBands().getUpperBand())
    plt.getInstrumentSubplot(instrument).addDataSeries("middle", myStrategy.getBollingerBands().getMiddleBand())
    plt.getInstrumentSubplot(instrument).addDataSeries("lower", myStrategy.getBollingerBands().getLowerBand())
    
# Attach different analyzers to a strategy before executing it.
retAnalyzer = returns.Returns()
myStrategy.attachAnalyzer(retAnalyzer)
sharpeRatioAnalyzer = sharpe.SharpeRatio()
myStrategy.attachAnalyzer(sharpeRatioAnalyzer)
drawDownAnalyzer = drawdown.DrawDown()
myStrategy.attachAnalyzer(drawDownAnalyzer)
tradesAnalyzer = trades.Trades()
myStrategy.attachAnalyzer(tradesAnalyzer)
    
# Run the strategy.
myStrategy.run()

print "Final portfolio value: $%.2f" % myStrategy.getResult()
print "Cumulative returns: %.2f %%" % (retAnalyzer.getCumulativeReturns()[-1] * 100)
print "Sharpe ratio: %.2f" % (sharpeRatioAnalyzer.getSharpeRatio(0.05))
print "Max. drawdown: %.2f %%" % (drawDownAnalyzer.getMaxDrawDown() * 100)
print "Longest drawdown duration: %s" % (drawDownAnalyzer.getLongestDrawDownDuration())

print
print "Total trades: %d" % (tradesAnalyzer.getCount())
if tradesAnalyzer.getCount() > 0:
    profits = tradesAnalyzer.getAll()
    print "Avg. profit: $%2.f" % (profits.mean())
    print "Profits std. dev.: $%2.f" % (profits.std())
    print "Max. profit: $%2.f" % (profits.max())
    print "Min. profit: $%2.f" % (profits.min())
    returns = tradesAnalyzer.getAllReturns()
    print "Avg. return: %2.f %%" % (returns.mean() * 100)
    print "Returns std. dev.: %2.f %%" % (returns.std() * 100)
    print "Max. return: %2.f %%" % (returns.max() * 100)
    print "Min. return: %2.f %%" % (returns.min() * 100)

print
print "Profitable trades: %d" % (tradesAnalyzer.getProfitableCount())
if tradesAnalyzer.getProfitableCount() > 0:
    profits = tradesAnalyzer.getProfits()
    print "Avg. profit: $%2.f" % (profits.mean())
    print "Profits std. dev.: $%2.f" % (profits.std())
    print "Max. profit: $%2.f" % (profits.max())
    print "Min. profit: $%2.f" % (profits.min())
    returns = tradesAnalyzer.getPositiveReturns()
    print "Avg. return: %2.f %%" % (returns.mean() * 100)
    print "Returns std. dev.: %2.f %%" % (returns.std() * 100)
    print "Max. return: %2.f %%" % (returns.max() * 100)
    print "Min. return: %2.f %%" % (returns.min() * 100)

print
print "Unprofitable trades: %d" % (tradesAnalyzer.getUnprofitableCount())
if tradesAnalyzer.getUnprofitableCount() > 0:
    losses = tradesAnalyzer.getLosses()
    print "Avg. loss: $%2.f" % (losses.mean())
    print "Losses std. dev.: $%2.f" % (losses.std())
    print "Max. loss: $%2.f" % (losses.min())
    print "Min. loss: $%2.f" % (losses.max())
    returns = tradesAnalyzer.getNegativeReturns()
    print "Avg. return: %2.f %%" % (returns.mean() * 100)
    print "Returns std. dev.: %2.f %%" % (returns.std() * 100)
    print "Max. return: %2.f %%" % (returns.max() * 100)
    print "Min. return: %2.f %%" % (returns.min() * 100)
    
if plot:
    plt.plot()
# Out:
# ('middle slope is', None, 'sell?', True)
# ('middle slope is', None, 'sell?', True)
# ('middle slope is', 0.12664606901571701, 'buy?', True)
# ('middle slope is', -0.29435719795308468, 'sell?', True)
# ('middle slope is', -0.16798158006197672, 'sell?', True)
# ('middle slope is', 0.0036240687267518356, 'buy?', True)
# ('middle slope is', -0.28368945453079875, 'sell?', True)
# ('middle slope is', 0.13500049949349172, 'buy?', True)
# ('middle slope is', 0.23881173488932833, 'buy?', True)
# ('middle slope is', -0.22461044118201723, 'sell?', True)
# ('middle slope is', -0.33032976989047219, 'sell?', True)
# ('middle slope is', 0.58491680366159027, 'buy?', True)
# ('middle slope is', 0.46451227356579583, 'buy?', True)
# ('middle slope is', 0.29509889360439023, 'buy?', True)
# ('middle slope is', 0.2102829463389832, 'buy?', True)
# ('middle slope is', -0.12498555623784281, 'sell?', True)
# ('middle slope is', -0.099973102894225271, 'sell?', True)
# ('middle slope is', -0.062099060751525853, 'sell?', True)
# ('middle slope is', 0.95520385366434724, 'buy?', True)
# ('middle slope is', 0.65143197803005171, 'buy?', True)
# ('middle slope is', 0.54212705915930615, 'buy?', True)
# ('middle slope is', -0.49740097892338769, 'sell?', True)
# ('middle slope is', -0.33975863628108505, 'sell?', True)
# ('middle slope is', -0.28645306747438665, 'sell?', True)
# ('middle slope is', -0.058422742347772824, 'sell?', True)
# ('middle slope is', 0.2039610023579522, 'buy?', True)
# ('middle slope is', 0.22205238215855633, 'buy?', True)
# ('middle slope is', 0.20866922619798683, 'buy?', True)
# ('middle slope is', -0.37072849390799828, 'sell?', True)
# ('middle slope is', -0.31436301216545565, 'sell?', True)
# ('middle slope is', -0.033794361373608466, 'sell?', True)
# ('middle slope is', 0.95783514332392927, 'buy?', True)
# ('middle slope is', 0.41888428893944996, 'buy?', True)
# ('middle slope is', -0.65606968969214896, 'sell?', True)
# ('middle slope is', -0.48471189385415742, 'sell?', True)
# ('middle slope is', 0.41149873077300941, 'buy?', True)
# ('middle slope is', 0.3915867326294028, 'buy?', True)
# ('middle slope is', 0.36798122061603766, 'buy?', True)
# ('middle slope is', 0.33805903602763704, 'buy?', True)
# ('middle slope is', 0.29927248559336977, 'buy?', True)
# ('middle slope is', -0.39621733690695959, 'sell?', True)
# ('middle slope is', -0.35494816512193039, 'sell?', True)
# ('middle slope is', 0.087273095215816984, 'buy?', True)
# ('middle slope is', 0.094886646079628587, 'buy?', True)
# ('middle slope is', 0.081294161209540514, 'buy?', True)
# ('middle slope is', -0.16087395027793086, 'sell?', True)
# ('middle slope is', 0.10458973802203195, 'buy?', True)
# ('middle slope is', 0.089855175952765723, 'buy?', True)
# ('middle slope is', -0.22107274187822479, 'sell?', True)
# ('middle slope is', 0.014249687224900878, 'buy?', True)
# ('middle slope is', 0.010085670409829172, 'buy?', True)
# ('middle slope is', 0.0041521199069116154, 'buy?', True)
# ('middle slope is', -0.23768760019636861, 'sell?', True)
# ('middle slope is', -0.069362773093493396, 'sell?', True)
# ('middle slope is', -0.071051556966298821, 'sell?', True)
# ('middle slope is', -0.10481452772520695, 'sell?', True)
# ('middle slope is', -0.0526244528985709, 'sell?', True)
# ('middle slope is', 0.092702543980590371, 'buy?', True)
# ('middle slope is', 0.037955982996293297, 'buy?', True)
# ('middle slope is', -0.25678950192258843, 'sell?', True)
# ('middle slope is', 0.21256246724304809, 'buy?', True)
# ('middle slope is', 0.19131781511620422, 'buy?', True)
# ('middle slope is', 0.15226588439352559, 'buy?', True)
# ('middle slope is', -0.10161734867276784, 'sell?', True)
# ('middle slope is', -0.099058405145978162, 'sell?', True)
# ('middle slope is', 0.036464803393878163, 'buy?', True)
# ('middle slope is', -0.10426602513125756, 'sell?', True)
# ('middle slope is', -0.093079697104623466, 'sell?', True)
# ('middle slope is', -0.031147941193743662, 'sell?', True)
# ('middle slope is', -0.1563698098281881, 'sell?', True)
# ('middle slope is', 0.022609697461350605, 'buy?', True)
# ('middle slope is', -0.13778537761679197, 'sell?', True)
# ('middle slope is', -0.030815704668365366, 'sell?', True)
# ('middle slope is', -0.0016185070388546688, 'sell?', True)
# ('middle slope is', -0.037645776532608359, 'sell?', True)
# ('middle slope is', -0.046397790547983556, 'sell?', True)
# ('middle slope is', -0.030607694631845331, 'sell?', True)
# ('middle slope is', 0.12847770270516645, 'buy?', True)
# ('middle slope is', 0.094920669327232671, 'buy?', True)
# ('middle slope is', 0.059887759259896797, 'buy?', True)
# ('middle slope is', 0.023570084265805424, 'buy?', True)
# ('middle slope is', -0.10522377971798071, 'sell?', True)
# ('middle slope is', -0.088094552070610982, 'sell?', True)
# ('middle slope is', -0.071219251953741139, 'sell?', True)
# ('middle slope is', -0.12048698582188283, 'sell?', True)
# ('middle slope is', -0.85847979230485993, 'sell?', True)
# ('middle slope is', -0.45276081031252247, 'sell?', True)
# ('middle slope is', 0.058496995272232545, 'buy?', True)
# ('middle slope is', -0.12235368812405885, 'sell?', True)
# ('middle slope is', -0.083398796308418038, 'sell?', True)
# ('middle slope is', -0.063228744950691626, 'sell?', True)
# ('middle slope is', -0.018480830418279533, 'sell?', True)
# ('middle slope is', 0.14746199125464163, 'buy?', True)
